# %% [markdown]
# List of 3 possible questions related to mental health
#
# Natural events affects emotionally and financially
#
# Number of suicides because of inflation
#
# Cases Suicides reported up to a year
