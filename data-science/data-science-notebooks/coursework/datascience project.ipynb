# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
suicides = pd.read_csv('suicides.csv')
suicides
# Out:
#                                                    Year       State Deaths  \
# 0                                                  2020     Alabama    793
# 1                                                  2020      Alaska    204
# 2                                                  2020     Arizona  1,363
# 3                                                  2020    Arkansas    583
# 4                                                  2020  California  4,144
# ...                                                 ...         ...    ...
# 1030                                    Race: All Races         NaN    NaN
# 1031                         Ethnicity: All Ethnicities         NaN    NaN
# 1032         Metro / Non-Metro Indicator: None Selected         NaN    NaN
# 1033                                       YPLL Age: 65         NaN    NaN
# 1034  Produced by: National Center for Injury Preven...         NaN    NaN
#
# ...

# %%
read_file = pd.read_excel ("disasters.xlsx")
# Out:
# ~/opt/anaconda3/lib/python3.9/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
read_file.to_csv ("Test.csv", 
                  index = None,
                  header=True)

# %%
disasters = pd.DataFrame(pd.read_csv("Test.csv"))

# %%
disasters
# Out:
#              Source: EM-DAT, CRED / UCLouvain, Brussels, Belgium Unnamed: 2  \
# 0                NaN                                www.emdat.be        NaN
# 1           Version:                                  2023-05-08        NaN
# 2     File creation:              Mon, 08 May 2023 19:13:26 CEST        NaN
# 3        Table type:                              Custom request        NaN
# 4      # of records:                                        1364        NaN
# ...              ...                                         ...        ...
# 1365   2023-0032-USA                                        2023       0032
# 1366   2023-0176-USA                                        2023       0176
# 1367   2023-0192-USA                                        2023       0192
# 1368   2023-0206-USA                                        2023       0206
# 1369   2023-0122-USA                                        2023       0122
#
# ...
