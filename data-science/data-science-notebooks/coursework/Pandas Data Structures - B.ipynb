# %% [markdown]
# # Pandas Data Structures - Cont
#
# ## Basic Math and Statistical Operations

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('ConfirmedFSMarch2023.csv')
df
# Out:
#                                       Unnamed: 0 Unnamed: 1 Unnamed: 2  \
# 0                          Confirmed FS Schedule        NaN        NaN
# 1      Effective March 1, 2023 to March 31, 2023        NaN        NaN
# 2                                            NaN        NaN        NaN
# 3                                         Origin      Dest.     Flight
# 4                                        Airport    Airport     Number
# ...                                          ...        ...        ...
# 10628                                        NaN        NaN        NaN
# 10629                                        NaN        NaN        NaN
# 10630                                        NaN        NaN        NaN
# 10631                                        NaN        NaN        NaN
# 10632                                        NaN        NaN        NaN
#
#       Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# ...

# %%
aveHappi = df['HappinessScore'].sum()/len(df)
aveHappi
# Out:
# 5.398907142857143

# %%
aveHappi =  df['HappinessScore'].mean()
aveHappi
# Out:
# 5.3989071428571425

# %%
sum(df['HappinessScore'])/len(df)
# Out:
# 5.3989071428571425

# %%
df.sum()
# Out:
# Country                              NorwayDenmarkIcelandSwitzerlandFinlandNetherla...
# Region                               Western EuropeWestern EuropeWestern EuropeWest...
# Rank                                                                              9870
# HappinessScore                                                                 755.847
# Life Ladder                                                                 768.838288
# Log GDP per capita                                                         1242.966817
# Social support                                                              112.132889
# Healthy life expectancy at birth                                           8881.737408
# Freedom to make life choices                                                108.124485
# Generosity                                                                   -1.532985
# Perceptions of corruption                                                    94.191357
# ...

# %%
df.sum(axis = 1)
# Out:
# 0      102.416253
# 1      103.363037
# 2      105.772921
# 3      107.245193
# 4      106.233556
#           ...
# 135    207.313663
# 136    208.003508
# 137    208.802030
# 138    214.406951
# 139    194.532106
# Length: 140, dtype: float64

# %%
df.Country.dtype
# Out:
# dtype('O')

# %%
df.dtypes
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 140 entries, 0 to 139
# Data columns (total 14 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Country                            140 non-null    object
#  1   Region                             140 non-null    object
#  2   Rank                               140 non-null    int64
#  3   HappinessScore                     140 non-null    float64
#  4   Life Ladder                        140 non-null    float64
#  5   Log GDP per capita                 133 non-null    float64
#  6   Social support                     139 non-null    float64
#  7   Healthy life expectancy at birth   140 non-null    float64
#  8   Freedom to make life choices       139 non-null    float64
#  9   Generosity                         132 non-null    float64
#  10  Perceptions of corruption          128 non-null    float64
# ...

# %%
df.iloc[[0]].sum()
# df.iloc[0].sum() producirá error ya que tratará de sumar todos los valores de una sola fila (sumar todas las columnas en una fila, incluyendo strings con ints and floats)
# Si quiere sumar solamente los valores numéricos de una fila, debe hacer slicing:
# df.iloc[0, 2:].sum()
# Out:
# 102.41625334699998

# %%
df.iloc[3:5].sum()
# loc for labels
# Out:
# Country                                        SwitzerlandFinland
# Region                               Western EuropeWestern Europe
# Rank                                                            9
# HappinessScore                                             14.963
# Life Ladder                                             15.261845
# Log GDP per capita                                      21.567886
# Social support                                           1.913488
# Healthy life expectancy at birth                        144.87072
# Freedom to make life choices                             1.887196
# Generosity                                               0.155701
# Perceptions of corruption                                0.508596
# Positive affect                                          1.561134
# Negative affect                                          0.371937
# Confidence in national government                        1.417245
# dtype: object

# %%
minIn = df['HappinessScore'].idxmin()
df.iloc[minIn]
# Out:
# Country                              Central African Republic
# Region                                     Sub-Saharan Africa
# Rank                                                      140
# HappinessScore                                          2.693
# Life Ladder                                          3.475862
# Log GDP per capita                                        NaN
# Social support                                       0.319589
# Healthy life expectancy at birth                    44.645351
# Freedom to make life choices                         0.645252
# Generosity                                                NaN
# Perceptions of corruption                            0.889566
# Positive affect                                      0.613865
# Negative affect                                      0.599335
# Confidence in national government                    0.650285
# Name: 139, dtype: object

# %%
df['HappinessScore']>5
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 135    False
# 136    False
# 137    False
# 138    False
# 139    False
# Name: HappinessScore, Length: 140, dtype: bool

# %%
df.loc[df['HappinessScore']>5]
df[df['HappinessScore']>5]
# Out:
#         Country                              Region  Rank  HappinessScore  \
# 0        Norway                      Western Europe     1           7.537
# 1       Denmark                      Western Europe     2           7.522
# 2       Iceland                      Western Europe     3           7.504
# 3   Switzerland                      Western Europe     4           7.494
# 4       Finland                      Western Europe     5           7.469
# ..          ...                                 ...   ...             ...
# 84    Macedonia          Central and Eastern Europe    85           5.175
# 85      Nigeria                  Sub-Saharan Africa    86           5.074
# 86      Vietnam                      Southeast Asia    87           5.074
# 87   Tajikistan  Commonwealth of Independent States    88           5.041
# 88   Kyrgyzstan  Commonwealth of Independent States    89           5.004
#
#     Life Ladder  Log GDP per capita  Social support  \
# ...

# %%
df.loc[df['HappinessScore']>5,['Region','Rank']]
# Out:
#                                 Region  Rank
# 0                       Western Europe     1
# 1                       Western Europe     2
# 2                       Western Europe     3
# 3                       Western Europe     4
# 4                       Western Europe     5
# ..                                 ...   ...
# 84          Central and Eastern Europe    85
# 85                  Sub-Saharan Africa    86
# 86                      Southeast Asia    87
# 87  Commonwealth of Independent States    88
# 88  Commonwealth of Independent States    89
#
# [89 rows x 2 columns]

# %%
df.loc[(df['HappinessScore']>5) & (df['Log GDP per capita']<8),['Region','Rank']]
# Out:
#                                 Region  Rank
# 87  Commonwealth of Independent States    88

# %%
# Use al final ya que lo que devuelve no es el DF sino un "styler".
# df.style.set_properties(**{'text-align':'left'}).set_table_styles([dict(selector='th', props=[('text-align', 'left')])])
# Out:
# <style  type="text/css" >
#     #T_eb10d_ th {
#           text-align: left;
# ...
