# %%
import nbformat as nbf
import os
import glob

# %%
    
# Define a function to combine notebooks
def combine_notebooks(filenames):
    merged_notebook = nbf.v4.new_notebook()
    for filename in filenames:
        with open(filename) as f:
            notebook = nbf.read(f, as_version=4)
            merged_notebook.cells.extend(notebook.cells)
    return merged_notebook

# %%
# Gather list of all ipynb files
ipynb_files = glob.glob('*.ipynb')

# %%
ipynb_files
# Out:
# ['Viz3.ipynb',
#  'covid dataframe.ipynb',
#  'visualization_Part1.ipynb',
#  'datascience project.ipynb',
#  'union.ipynb',
#  'dataWrang-Asignacion.ipynb',
#  'Pandas Data Structures - A.ipynb',
#  'merged_notebook.ipynb',
#  'dataWrang_Final.ipynb',
#  'dataCleaningandWrang.ipynb',
#  'dataWrang-Cont.ipynb',
#  'Pandas Data Structures - B.ipynb']

# %%
# Combine notebooks
merged = combine_notebooks(ipynb_files)

# Write the combined notebook to a new file

# %%
with open('merged_notebookpart1.ipynb', 'w') as f:
    nbf.write(merged, f)
# Out:
# ~/opt/anaconda3/lib/python3.9/site-packages/nbformat/__init__.py:128: DuplicateCellId: Non-unique cell id '94555837' detected. Corrected to '8ec17b03'.
#   validate(nb)
# ~/opt/anaconda3/lib/python3.9/site-packages/nbformat/__init__.py:128: DuplicateCellId: Non-unique cell id 'edff54ff' detected. Corrected to '667f8b95'.
#   validate(nb)
# ~/opt/anaconda3/lib/python3.9/site-packages/nbformat/__init__.py:128: DuplicateCellId: Non-unique cell id 'ee51f126' detected. Corrected to 'eee4aab1'.
#   validate(nb)
# ~/opt/anaconda3/lib/python3.9/site-packages/nbformat/__init__.py:128: DuplicateCellId: Non-unique cell id '99629fa6' detected. Corrected to 'dee42534'.
#   validate(nb)
# ~/opt/anaconda3/lib/python3.9/site-packages/nbformat/__init__.py:128: DuplicateCellId: Non-unique cell id '4011af95' detected. Corrected to 'c31d9b44'.
#   validate(nb)
# ~/opt/anaconda3/lib/python3.9/site-packages/nbformat/__init__.py:128: DuplicateCellId: Non-unique cell id '0cea7dec' detected. Corrected to 'c1ef46b5'.
#   validate(nb)
# ~/opt/anaconda3/lib/python3.9/site-packages/nbformat/__init__.py:128: DuplicateCellId: Non-unique cell id '008dfb31' detected. Corrected to 'f4c9cfc3'.
#   validate(nb)
# ~/opt/anaconda3/lib/python3.9/site-packages/nbformat/__init__.py:128: DuplicateCellId: Non-unique cell id '0e3c8847' detected. Corrected to 'a58b6df0'.
#   validate(nb)
# ~/opt/anaconda3/lib/python3.9/site-packages/nbformat/__init__.py:128: DuplicateCellId: Non-unique cell id 'e1f179a8' detected. Corrected to '09771d80'.
#   validate(nb)
# ~/opt/anaconda3/lib/python3.9/site-packages/nbformat/__init__.py:128: DuplicateCellId: Non-unique cell id 'd13c21a8' detected. Corrected to '1b59d002'.
#   validate(nb)
# ~/opt/anaconda3/lib/python3.9/site-packages/nbformat/__init__.py:128: DuplicateCellId: Non-unique cell id '303f069d' detected. Corrected to 'ed07fbc9'.
#   validate(nb)
# ~/opt/anaconda3/lib/python3.9/site-packages/nbformat/__init__.py:128: DuplicateCellId: Non-unique cell id '6b5a7213' detected. Corrected to '4a1e852a'.
#   validate(nb)
# ~/opt/anaconda3/lib/python3.9/site-packages/nbformat/__init__.py:128: DuplicateCellId: Non-unique cell id '08bc91c2' detected. Corrected to '3618b023'.
#   validate(nb)
# ~/opt/anaconda3/lib/python3.9/site-packages/nbformat/__init__.py:128: DuplicateCellId: Non-unique cell id 'ff187a47' detected. Corrected to '3014660b'.
#   validate(nb)
# ~/opt/anaconda3/lib/python3.9/site-packages/nbformat/__init__.py:128: DuplicateCellId: Non-unique cell id 'fc1f0e1e' detected. Corrected to '796b729e'.
#   validate(nb)
# ~/opt/anaconda3/lib/python3.9/site-packages/nbformat/__init__.py:128: DuplicateCellId: Non-unique cell id '0a0ff2af' detected. Corrected to 'aea65153'.
#   validate(nb)
# ~/opt/anaconda3/lib/python3.9/site-packages/nbformat/__init__.py:128: DuplicateCellId: Non-unique cell id '23b24e02' detected. Corrected to '40f9b55c'.
#   validate(nb)
# ~/opt/anaconda3/lib/python3.9/site-packages/nbformat/__init__.py:128: DuplicateCellId: Non-unique cell id 'e3989696' detected. Corrected to '98b4ab5d'.
#   validate(nb)
# ~/opt/anaconda3/lib/python3.9/site-packages/nbformat/__init__.py:128: DuplicateCellId: Non-unique cell id 'a6b043ab' detected. Corrected to 'd0a19100'.
#   validate(nb)
# ~/opt/anaconda3/lib/python3.9/site-packages/nbformat/__init__.py:128: DuplicateCellId: Non-unique cell id '1135da3c' detected. Corrected to '4d38839c'.
#   validate(nb)
# ~/opt/anaconda3/lib/python3.9/site-packages/nbformat/__init__.py:128: DuplicateCellId: Non-unique cell id '26250f05' detected. Corrected to '2dbc5d02'.
#   validate(nb)
# ~/opt/anaconda3/lib/python3.9/site-packages/nbformat/__init__.py:128: DuplicateCellId: Non-unique cell id 'a3a98d20' detected. Corrected to '09d56975'.
#   validate(nb)
# ~/opt/anaconda3/lib/python3.9/site-packages/nbformat/__init__.py:128: DuplicateCellId: Non-unique cell id '4068e884' detected. Corrected to '123863c7'.
#   validate(nb)
# ~/opt/anaconda3/lib/python3.9/site-packages/nbformat/__init__.py:128: DuplicateCellId: Non-unique cell id '166e33bf' detected. Corrected to '945febca'.
#   validate(nb)
# ~/opt/anaconda3/lib/python3.9/site-packages/nbformat/__init__.py:128: DuplicateCellId: Non-unique cell id '3619b72d' detected. Corrected to '49f24014'.
#   validate(nb)
# ~/opt/anaconda3/lib/python3.9/site-packages/nbformat/__init__.py:128: DuplicateCellId: Non-unique cell id '78d85e54' detected. Corrected to '6050795e'.
#   validate(nb)
# ~/opt/anaconda3/lib/python3.9/site-packages/nbformat/__init__.py:128: DuplicateCellId: Non-unique cell id 'fde34f21' detected. Corrected to '8a09cbcd'.
#   validate(nb)
# ~/opt/anaconda3/lib/python3.9/site-packages/nbformat/__init__.py:128: DuplicateCellId: Non-unique cell id '8a08a5be' detected. Corrected to '429c0fcc'.
#   validate(nb)
# ~/opt/anaconda3/lib/python3.9/site-packages/nbformat/__init__.py:128: DuplicateCellId: Non-unique cell id '9b765325' detected. Corrected to '3ba259b9'.
#   validate(nb)
# ~/opt/anaconda3/lib/python3.9/site-packages/nbformat/__init__.py:128: DuplicateCellId: Non-unique cell id '3a10b923' detected. Corrected to '0010dff7'.
#   validate(nb)
# ~/opt/anaconda3/lib/python3.9/site-packages/nbformat/__init__.py:128: DuplicateCellId: Non-unique cell id 'b4ac9e5b' detected. Corrected to '941a4263'.
#   validate(nb)
# ~/opt/anaconda3/lib/python3.9/site-packages/nbformat/__init__.py:128: DuplicateCellId: Non-unique cell id '443c169d' detected. Corrected to '9ffd66df'.
#   validate(nb)
# ~/opt/anaconda3/lib/python3.9/site-packages/nbformat/__init__.py:128: DuplicateCellId: Non-unique cell id '081aa8fe' detected. Corrected to 'ad954c3b'.
#   validate(nb)
# ~/opt/anaconda3/lib/python3.9/site-packages/nbformat/__init__.py:128: DuplicateCellId: Non-unique cell id 'cd030d76' detected. Corrected to '8749c9e0'.
#   validate(nb)
# ~/opt/anaconda3/lib/python3.9/site-packages/nbformat/__init__.py:128: DuplicateCellId: Non-unique cell id 'f94b04b2' detected. Corrected to '6ed92d30'.
#   validate(nb)
# ~/opt/anaconda3/lib/python3.9/site-packages/nbformat/__init__.py:128: DuplicateCellId: Non-unique cell id '563ac45b' detected. Corrected to '23390537'.
#   validate(nb)
# ~/opt/anaconda3/lib/python3.9/site-packages/nbformat/__init__.py:128: DuplicateCellId: Non-unique cell id