# %%
from Bio.Seq import Seq

# %%
my_seq = Seq("AGTACACTGGT")

# %%
my_seq
# Out:
# Seq('AGTACACTGGT')

# %%
print(my_seq)
# Out:
# AGTACACTGGT

# %%
my_seq.complement()
# Out:
# Seq('TCATGTGACCA')

# %%
my_seq.reverse_complement()
# Out:
# Seq('ACCAGTGTACT')
