# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('ConfirmedFSMarch2023.csv', skiprows =[0,1,2,3,6,7],skipfooter=2272,engine='python')

# %%
df
# Out:
#        Origin    Dest.  Flight   Flight.1 Departure Arrival Aircraft Subfleet  \
# 0     Airport  Airport  Number  Frequency      Time    Time     Type     Type
# 1         ABQ      AUS    3678    12345.7     16:05   18:49      E75      E7M
# 2         ABQ      DFW    0942    ..34...     14:55   17:36      321      A21
# 3         ABQ      DFW    1421    ..34...      7:49   10:33      738      38K
# 4         ABQ      DFW    1670    ..34...     12:06   14:49      738      38K
# ...       ...      ...     ...        ...       ...     ...      ...      ...
# 8350      YYZ      MIA    2589    1234567      6:00    9:31      319      19W
# 8351      YYZ      MIA    1572    12345.7     17:59   21:19      319      19W
# 8352      ZRH      PHL    0093    .2.4567     10:15   13:11      788      788
# 8353      ZRH      PHL    0093    .2.4567     10:15   14:11      788      788
# 8354      ZRH      PHL    0093    12345.7     11:45   14:41      788      788
#
#       Effective Discontinue
# ...

# %%
df.rename(columns = {"Flight.1":"Flight"}, inplace=True)
df.columns = df.columns + ' ' +df.loc[0]

# %%
df
# Out:
#      Origin Airport Dest. Airport Flight Number Flight Frequency  \
# 0           Airport       Airport        Number        Frequency
# 1               ABQ           AUS          3678          12345.7
# 2               ABQ           DFW          0942          ..34...
# 3               ABQ           DFW          1421          ..34...
# 4               ABQ           DFW          1670          ..34...
# ...             ...           ...           ...              ...
# 8350            YYZ           MIA          2589          1234567
# 8351            YYZ           MIA          1572          12345.7
# 8352            ZRH           PHL          0093          .2.4567
# 8353            ZRH           PHL          0093          .2.4567
# 8354            ZRH           PHL          0093          12345.7
#
#      Departure Time Arrival Time Aircraft Type Subfleet Type Effective Date  \
# 0              Time         Time          Type          Type           Date
# ...

# %%
df.drop([0],inplace=True)

# %%
df.reset_index(drop=True)
# Out:
#      Origin Airport Dest. Airport Flight Number Flight Frequency  \
# 0               ABQ           AUS          3678          12345.7
# 1               ABQ           DFW          0942          ..34...
# 2               ABQ           DFW          1421          ..34...
# 3               ABQ           DFW          1670          ..34...
# 4               ABQ           DFW          0928          1234567
# ...             ...           ...           ...              ...
# 8349            YYZ           MIA          2589          1234567
# 8350            YYZ           MIA          1572          12345.7
# 8351            ZRH           PHL          0093          .2.4567
# 8352            ZRH           PHL          0093          .2.4567
# 8353            ZRH           PHL          0093          12345.7
#
#      Departure Time Arrival Time Aircraft Type Subfleet Type Effective Date  \
# 0             16:05        18:49           E75           E7M       1-Mar-23
# ...

# %%
df
# Out:
#      Origin Airport Dest. Airport Flight Number Flight Frequency  \
# 1               ABQ           AUS          3678          12345.7
# 2               ABQ           DFW          0942          ..34...
# 3               ABQ           DFW          1421          ..34...
# 4               ABQ           DFW          1670          ..34...
# 5               ABQ           DFW          0928          1234567
# ...             ...           ...           ...              ...
# 8350            YYZ           MIA          2589          1234567
# 8351            YYZ           MIA          1572          12345.7
# 8352            ZRH           PHL          0093          .2.4567
# 8353            ZRH           PHL          0093          .2.4567
# 8354            ZRH           PHL          0093          12345.7
#
#      Departure Time Arrival Time Aircraft Type Subfleet Type Effective Date  \
# 1             16:05        18:49           E75           E7M       1-Mar-23
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8354 entries, 1 to 8354
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Origin Airport     8354 non-null   object
#  1   Dest. Airport      8354 non-null   object
#  2   Flight Number      8354 non-null   object
#  3   Flight Frequency   8354 non-null   object
#  4   Departure Time     8354 non-null   object
#  5   Arrival Time       8354 non-null   object
#  6   Aircraft Type      8354 non-null   object
#  7   Subfleet Type      8354 non-null   object
#  8   Effective Date     8354 non-null   object
#  9   Discontinue  Date  8354 non-null   object
# dtypes: object(10)
# memory usage: 652.8+ KB

# %%
df[df['Origin Airport']=="SJU"]
# Out:
#      Origin Airport Dest. Airport Flight Number Flight Frequency  \
# 7904            SJU           CLT          1836          ..34...
# 7905            SJU           CLT          0783          1234567
# 7906            SJU           CLT          1836          1234567
# 7907            SJU           CLT          1038          .....6.
# 7908            SJU           CLT          1038          .....6.
# 7909            SJU           CLT          1836          1234567
# 7910            SJU           CLT          0783          1234567
# 7911            SJU           CLT          1038          .....6.
# 7912            SJU           CLT          1836          12345.7
# 7913            SJU           DFW          2196          1234567
# 7914            SJU           DFW          2196          1234567
# 7915            SJU           MIA          0321          1234567
# 7916            SJU           MIA          1613          1234567
# ...

# %%
'321' in df['Aircraft Type'].values
# Out:
# True

# %%
df[(df[('Origin Airport']=="SJU") & (df['Aircraft Type'] !="321"))  ]
# Out:
#   File "/var/folders/qt/65npn54j14qfbrg0py18sw_80000gn/T/ipykernel_55520/890901167.py", line 1
#     df[df('Origin Airport']=="SJU") & (df['Aircraft Type'] !="321")  ]
#                           ^
# SyntaxError: closing parenthesis ']' does not match opening parenthesis '('
