# %%
Panda series
# Out:
#   File "/var/folders/qt/65npn54j14qfbrg0py18sw_80000gn/T/ipykernel_12939/3517090353.py", line 1
#     panda series
#           ^
# SyntaxError: invalid syntax

# %%
import numpy as np
import pandas as pd

# %%
data1 =[1,2,3,4,"hola"]

# %%
dataS = pd.Series(data1)

# %%
dataS
# Out:
# 0       1
# 1       2
# 2       3
# 3       4
# 4    hola
# dtype: object

# %%
dataS.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
dataR = np.random.rand(10000)

# %%
# %timeit sum(dataR)
# Out:
# 695 µs ± 7.06 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
# %timeit np.sum(dataR)
# Out:
# 4.6 µs ± 39.4 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
dataS.index = ["Primero","segundo","tercero","cuarto","quinto"]

# %%
dataS
# Out:
# Primero       1
# segundo       2
# tercero       3
# cuarto        4
# quinto     hola
# dtype: object

# %%
data2 = {'nombre':['Luis','Miguel','Pedro'],
        'id':['801000020','801000021','801000022'],
        'gpa':[3.80,4.00,3.99] }

# %%
data2
# Out:
# {'nombre': ['Luis', 'Miguel', 'Pedro'],
#  'id': ['801000020', '801000021', '801000022'],
#  'gpa': [3.8, 4.0, 3.99]}

# %%
dataF = pd.DataFrame(data2)

# %%
dataF
# Out:
#    nombre         id   gpa
# 0    Luis  801000020  3.80
# 1  Miguel  801000021  4.00
# 2   Pedro  801000022  3.99

# %%
dataF.sort_values(dataF, by = 'nombre')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/qt/65npn54j14qfbrg0py18sw_80000gn/T/ipykernel_12939/2862686906.py in <module>
# ----> 1 dataF.sort_values(dataF, by = 'nombre')
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# TypeError: sort_values() got multiple values for argument 'by'

# %%
dataF.index += 1

# %%
dataF
# Out:
#    nombre         id   gpa
# 1    Luis  801000020  3.80
# 2  Miguel  801000021  4.00
# 3   Pedro  801000022  3.99

# %%
matx = np.random.rand(5,8)

# %%
 np.savetxt("jupyter/data3.csv", matx)

# %%
data3 = np.loadtxt("jupyter/data3.csv")

# %%
data3
# Out:
# array([[0.6595928 , 0.7100672 , 0.18518559, 0.38114723, 0.4956687 ,
#         0.98215481, 0.20184067, 0.12946689],
#        [0.68040366, 0.32891935, 0.19996393, 0.12422262, 0.34264305,
#         0.16481267, 0.56614039, 0.40167734],
#        [0.20266478, 0.86586669, 0.47463046, 0.00742947, 0.73526504,
#         0.25779451, 0.25963731, 0.18850704],
#        [0.0387881 , 0.34746691, 0.73046799, 0.14894617, 0.01764354,
#         0.71769897, 0.89120899, 0.20920022],
#        [0.55180989, 0.00889509, 0.67415659, 0.83702011, 0.41277905,
#         0.79579599, 0.1764008 , 0.56652198]])

# %%
datad2 = pd.read_csv("jupyter/data3.csv")

# %%
datad2
# Out:
#   6.595927950576663257e-01 7.100672034166385371e-01 1.851855946455592816e-01 3.811472265202827669e-01 4.956687014457857865e-01 9.821548148403390632e-01 2.018406704423522102e-01 1.294668920432036074e-01
# 0  6.804036590234535664e-01 3.289193529250904469e...
# 1  2.026647848608045255e-01 8.658666924103116669e...
# 2  3.878810295822809895e-02 3.474669120711457726e...
# 3  5.518098873342722754e-01 8.895093090465988617e...

# %%
dataF2 = pd.DataFrame(data3,columns = ["largo","ancho","prof","alt","masa","radio","vol","dens"])

# %%
dataF2
# Out:
#       largo     ancho      prof       alt      masa     radio       vol  \
# 0  0.659593  0.710067  0.185186  0.381147  0.495669  0.982155  0.201841
# 1  0.680404  0.328919  0.199964  0.124223  0.342643  0.164813  0.566140
# 2  0.202665  0.865867  0.474630  0.007429  0.735265  0.257795  0.259637
# 3  0.038788  0.347467  0.730468  0.148946  0.017644  0.717699  0.891209
# 4  0.551810  0.008895  0.674157  0.837020  0.412779  0.795796  0.176401
#
#        dens
# 0  0.129467
# 1  0.401677
# 2  0.188507
# 3  0.209200
# 4  0.566522

# %%
dataF2['area']= dataF2['largo'] = dataF2['ancho']

# %%
# Out:
#   File "/var/folders/qt/65npn54j14qfbrg0py18sw_80000gn/T/ipykernel_12939/1588554183.py", line 1
#     √
#     ^
# SyntaxError: invalid character '√' (U+221A)

# %%
dataF2
# Out:
#       largo     ancho      prof       alt      masa     radio       vol  \
# 0  0.710067  0.710067  0.185186  0.381147  0.495669  0.982155  0.201841
# 1  0.328919  0.328919  0.199964  0.124223  0.342643  0.164813  0.566140
# 2  0.865867  0.865867  0.474630  0.007429  0.735265  0.257795  0.259637
# 3  0.347467  0.347467  0.730468  0.148946  0.017644  0.717699  0.891209
# 4  0.008895  0.008895  0.674157  0.837020  0.412779  0.795796  0.176401
#
#        dens      area
# 0  0.129467  0.710067
# 1  0.401677  0.328919
# 2  0.188507  0.865867
# 3  0.209200  0.347467
# 4  0.566522  0.008895
