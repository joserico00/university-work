# %%
# import the pandas package under the alias pd
import pandas as pd
import matplotlib.pyplot as plt
import geopandas as gpd
import numpy as np
# create a variable to hold the excel file name (optional - can also put the filename directly into the read_excel() function) 
file = 'data/eaglei_outages/eaglei_outages_2016.csv' # make sure this file is downloaded and placed in the data folder
# create a variable to hold the pandas DataFrame object
outrages = pd.read_csv(file, delimiter=',', skiprows=0, low_memory=False)

# prints the DataFrame to the screen
outrages
# Out:
# ~/.local/perlmutter/3.9-anaconda-2021.11/lib/python3.9/site-packages/geopandas/_compat.py:124: UserWarning: The Shapely GEOS version (3.8.0-CAPI-1.13.1 ) is incompatible with the GEOS version PyGEOS was compiled with (3.10.4-CAPI-1.16.2). Conversions between both will be slow.
#   warnings.warn(
#           fips_code           county          state  sum       run_start_time
# 0              2122  Kenai Peninsula         Alaska  657  2016-01-01 00:00:00
# 1              5003           Ashley       Arkansas    7  2016-01-01 00:00:00
# 2              5029           Conway       Arkansas    2  2016-01-01 00:00:00
# 3              5069        Jefferson       Arkansas   41  2016-01-01 00:00:00
# 4              5081     Little River       Arkansas   61  2016-01-01 00:00:00
# ...             ...              ...            ...  ...                  ...
# 13306019      54061       Monongalia  West Virginia  472  2016-12-31 00:00:00
# ...

# %%
file = 'data/temperaturedata/CtyAvTemp61716.csv' # make sure this file is downloaded and placed in the data folder
# create a variable to hold the pandas DataFrame object
temperature = pd.read_csv(file, delimiter=',', skiprows=0, low_memory=False)

# prints the DataFrame to the screen
temperature
temperature['TempF'] = temperature['TempK'].apply(lambda x: (x - 273.15) * 9/5 + 32)

# %%
temperature61716 = temperature.loc[(temperature["STATEFP"].isin([6 , 32 , 4]))]
                                   
temperature61716=temperature61716.sort_values(by='TempK')

# %%
temperature61716.tail(10)
# Out:
#       OBJECTID_1  FID_1  STATEFP  COUNTYFP  COUNTYNS  GEOID        NAME  \
# 2440        2441    850        4        11     42807   4011    Greenlee
# 2437        2438   1793        4         9     25444   4009      Graham
# 2436        2437   1729        4         7     40471   4007        Gila
# 2435        2436    405        4        21     25447   4021       Pinal
# 2432        2433    398        4        27     23901   4027        Yuma
# 2433        2434   2389        4        12     43540   4012      La Paz
# 2434        2435    851        4        13     37026   4013    Maricopa
# 2734        2735   1107        4         3     25442   4003     Cochise
# 2733        2734    912        4        19     25446   4019        Pima
# 2735        2736   2553        4        23     40472   4023  Santa Cruz
#
#                NAMELSAD  LSAD CLASSFP  ...    INTPTLON OBJECTID        Lat  \
# 2440    Greenlee County     6      H1  ... -109.242323     5703  33.332802
# ...

# %%
temperature61716
# Out:
#       OBJECTID_1  FID_1  STATEFP  COUNTYFP  COUNTYNS  GEOID        NAME  \
# 782          783    711        6        35   1693324   6035      Lassen
# 783          784   1807        6        49    277289   6049       Modoc
# 784          785   2041       32        31    858608  32031      Washoe
# 778          779    779        6        89   1682610   6089      Shasta
# 779          780   1953        6       103   1692767   6103      Tehama
# ...          ...    ...      ...       ...       ...    ...         ...
# 2433        2434   2389        4        12     43540   4012      La Paz
# 2434        2435    851        4        13     37026   4013    Maricopa
# 2734        2735   1107        4         3     25442   4003     Cochise
# 2733        2734    912        4        19     25446   4019        Pima
# 2735        2736   2553        4        23     40472   4023  Santa Cruz
#
#                NAMELSAD  LSAD CLASSFP  ...    INTPTLON OBJECTID        Lat  \
# ...

# %%
temperature61716.tail(10).plot.bar(x="NAMELSAD", y="TempF", rot=90, title="61716 temperature", ylabel="Temperature Farenheit", label="LA power outages",figsize=(25, 20), ylim=(60, 90))
# Out:
# <AxesSubplot:title={'center':'61716 temperature'}, xlabel='NAMELSAD', ylabel='Temperature Farenheit'>

# %%
#ctyavtemp61716_gdf = gpd.GeoDataFrame(temperature, geometry=gpd.points_from_xy(temperature['Lon'], temperature['Lat'], crs="EPSG:4326"))
#ctyavtemp61716_gdf

#world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# %%
#geoData = gpd.read_file('https://raw.githubusercontent.com/holtzy/The-Python-Graph-Gallery/master/static/data/US-counties.geojson')

# %%
#geoData

# %%
#uscounties_polygons_gdf.head()

# %%
#ctyavtemp61716_gdf.head()

# %%
outrages.state.unique()
# Out:
# array(['Alaska', 'Arkansas', 'California', 'Colorado', 'Connecticut',
#        'Delaware', 'District of Columbia', 'Florida', 'Georgia', 'Idaho',
#        'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana',
#        'Maine', 'Maryland', 'Massachusetts', 'Michigan', 'Minnesota',
#        'Mississippi', 'Missouri', 'Montana', 'New Hampshire',
#        'New Jersey', 'New Mexico', 'New York', 'North Carolina', 'Ohio',
#        'Oklahoma', 'Oregon', 'Pennsylvania', 'Rhode Island',
#        'South Carolina', 'South Dakota', 'Tennessee', 'Texas', 'Virginia',
#        'Washington', 'West Virginia', 'Wisconsin', 'Nebraska', 'Nevada',
#        'Arizona', 'Alabama', 'Vermont', 'North Dakota', 'Wyoming'],
#       dtype=object)

# %%
file = 'data/2016_HHSemPOWERMapHistoricalDataset.xlsx' # make sure this file is downloaded and placed in the data folder
# create a variable to hold the pandas DataFrame object

calcal2016 = pd.read_excel(file, sheet_name="County") 

# prints the DataFrame to the screen
medical2016
# Out:
#       FIPS_Code  County_FIPS_Code         County  State_FIPS_Code State  \
# 0          1001                 1       Autauga                 1   AL
# 1          1003                 3       Baldwin                 1   AL
# 2          1005                 5       Barbour                 1   AL
# 3          1007                 7          Bibb                 1   AL
# 4          1009                 9        Blount                 1   AL
# ...         ...               ...            ...              ...   ...
# 3223      72151               151       Yabucoa                72   PR
# 3224      72153               153         Yauco                72   PR
# 3225      78010                10   Saint Croix                78   VI
# 3226      78020                20    Saint John                78   VI
# 3227      78030                30  Saint Thomas                78   VI
#
#       Jan_2016_Medicare_Benes  Jan_2016_Power_Dependent_Devices_DME  \
# ...

# %%
southeastmed = medical2016.loc[(medical2016["State_FIPS_Code"].isin([6 , 32 , 4]))]

# %%
temperature.columns
# Out:
# Index(['OBJECTID_1', 'FID_1', 'STATEFP', 'COUNTYFP', 'COUNTYNS', 'GEOID',
#        'NAME', 'NAMELSAD', 'LSAD', 'CLASSFP', 'MTFCC', 'CSAFP', 'CBSAFP',
#        'METDIVFP', 'FUNCSTAT', 'ALAND', 'AWATER', 'INTPTLAT', 'INTPTLON',
#        'OBJECTID', 'Lat', 'Long', 'TempK', 'Lon2', 'Distance', 'Shape_Length',
#        'Shape_Area', 'TempF'],
#       dtype='object')

# %%
temperature['TempF'] = temperature['TempK'].apply(lambda x: (x - 273.15) * 9/5 + 32)

temperature=temperature.sort_values(by='TempK', ascending=False)


# we can combine two or more conditions in loc with the & symbol
# the & symbol between conditions indicates that both need to be satisfied for a given row

temperature.head(3)
# Out:
#       OBJECTID_1  FID_1  STATEFP  COUNTYFP  COUNTYNS  GEOID           NAME  \
# 2129        2130   1470       40       149   1101862  40149        Washita
# 2137        2138   2312       40        43   1101809  40043          Dewey
# 2130        2131   1503       48        87   1383829  48087  Collingsworth
#
#                   NAMELSAD  LSAD CLASSFP  ...    INTPTLON OBJECTID        Lat  \
# 2129        Washita County     6      H1  ...  -98.991436     5516  35.237499
# 2137          Dewey County     6      H1  ...  -99.014385     5516  35.237499
# 2130  Collingsworth County     6      H1  ... -100.272135     5516  35.237499
#
#          Long    TempK    Lon2  Distance  Shape_Length  Shape_Area   TempF
# 2129  260.625  305.625 -99.375  0.010359      2.341384    0.258892  90.455
# 2137  260.625  305.625 -99.375  0.574669      2.204524    0.260976  90.455
# 2130  260.625  305.625 -99.375  0.627781      1.951177    0.235005  90.455
#
# [3 rows x 28 columns]

# %%
file = 'data/temperaturedata/CtyAvTemp61816.csv' # make sure this file is downloaded and placed in the data folder
# create a variable to hold the pandas DataFrame object
temperature = pd.read_csv(file, delimiter=',', skiprows=0, low_memory=False)


temperature['TempF'] = temperature['TempK'].apply(lambda x: (x - 273.15) * 9/5 + 32)

# prints the DataFrame to the screen
temperature=temperature.sort_values(by='TempK', ascending=False)


# we can combine two or more conditions in loc with the & symbol
# the & symbol between conditions indicates that both need to be satisfied for a given row

temperature.head(10)
# Out:
#       OBJECTID_1  FID_1  STATEFP  COUNTYFP  COUNTYNS  GEOID      NAME  \
# 2744        2745    959       48         3   1383787  48003   Andrews
# 2750        2751   2841       48       475   1384023  48475      Ward
# 2743        2744    525       48       103   1383837  48103     Crane
# 2745        2746   1335       48       371   1383971  48371     Pecos
# 2746        2747   1411       48       495   1384033  48495   Winkler
# 2747        2748   2092       48       389   1383980  48389    Reeves
# 2748        2749   2274       48       135   1383853  48135     Ector
# 2749        2750   2529       48       301   1383936  48301    Loving
# 2983        2984   2772       48        43   1383807  48043  Brewster
# 2756        2757    940       48       317   1383941  48317    Martin
#
#              NAMELSAD  LSAD CLASSFP  ...      lon    TempK     Lat   Lon_12  \
# 2744   Andrews County     6      H1  ...  256.875  304.700  31.428  256.875
# ...

# %%
temperature61816 = temperature.loc[(temperature["STATEFP"].isin([6 , 32 , 4]))]
                            
temperature61816=temperature61816.sort_values(by='TempF')
temperature61816.tail(10).plot.bar(x="NAMELSAD", y="TempF", rot=90, title="61716 temperature", ylabel="Temperature Farenheit", label="LA power outages",figsize=(25, 20))
# Out:
# <AxesSubplot:title={'center':'61716 temperature'}, xlabel='NAMELSAD', ylabel='Temperature Farenheit'>

# %%
file = 'data/temperaturedata/CtyAvTemp61916.csv' # make sure this file is downloaded and placed in the data folder
# create a variable to hold the pandas DataFrame object
temperature = pd.read_csv(file, delimiter=',', skiprows=0, low_memory=False)
temperature['TempF'] = temperature['TempK'].apply(lambda x: (x - 273.15) * 9/5 + 32)

# prints the DataFrame to the screen
temperature=temperature.sort_values(by='TempK', ascending=False)


# we can combine two or more conditions in loc with the & symbol
# the & symbol between conditions indicates that both need to be satisfied for a given row

temperature.head(3)
# Out:
#      OBJECTID_1  STATEFP  COUNTYFP  GEOID      NAME        Lat         Lon  \
# 110        2433        4        27   4027      Yuma  32.773942 -113.910905
# 102        2434        4        12   4012    La Paz  33.727610 -114.038806
# 103        2435        4        13   4013  Maricopa  33.345176 -112.498930
#
#               Date_       TempK      TempF
# 110  6/19/2016 0:00  308.224976  95.134956
# 102  6/19/2016 0:00  308.224976  95.134956
# 103  6/19/2016 0:00  307.200012  93.290022

# %%
temperature61916 = temperature.loc[(temperature["STATEFP"].isin([6 , 32 , 4]))]
                                   
temperature61916=temperature61916.sort_values(by='TempF')
temperature61916.tail(10).plot.bar(x="NAME", y="TempF", rot=90, title="61716 temperature", ylabel="Temperature Farenheit", label="LA power outages",figsize=(25, 20))
# Out:
# <AxesSubplot:title={'center':'61716 temperature'}, xlabel='NAME', ylabel='Temperature Farenheit'>

# %%
file = 'data/temperaturedata/CtyAvTemp62016.csv' # make sure this file is downloaded and placed in the data folder
# create a variable to hold the pandas DataFrame object
temperature = pd.read_csv(file, delimiter=',', skiprows=0, low_memory=False)

# prints the DataFrame to the screen
temperature['TempF'] = temperature['TempK'].apply(lambda x: (x - 273.15) * 9/5 + 32)

temperature=temperature.sort_values(by='TempK', ascending=False)


# we can combine two or more conditions in loc with the & symbol
# the & symbol between conditions indicates that both need to be satisfied for a given row

temperature.head(3)
# Out:
#       OBJECTID_1  STATEFP  COUNTYFP  GEOID      NAME        Lat         Lon  \
# 2432        2433        4        27   4027      Yuma  32.773942 -113.910905
# 2433        2434        4        12   4012    La Paz  33.727610 -114.038806
# 2434        2435        4        13   4013  Maricopa  33.345176 -112.498930
#
#                Date_       TempK       TempF
# 2432  6/20/2016 0:00  312.075012  102.065022
# 2433  6/20/2016 0:00  312.075012  102.065022
# 2434  6/20/2016 0:00  309.399994   97.249989

# %%
temperature62016 = temperature.loc[(temperature["STATEFP"].isin([6 , 32 , 4]))]
                                   
temperature62016=temperature62016.sort_values(by='TempF')
temperature62016.tail(10).plot.bar(x="NAME", y="TempF", rot=90, title="61716 temperature", ylabel="Temperature Farenheit", label="LA power outages",figsize=(25, 20))
# Out:
# <AxesSubplot:title={'center':'61716 temperature'}, xlabel='NAME', ylabel='Temperature Farenheit'>

# %%
file = 'data/temperaturedata/CtyAvTemp62116.csv' # make sure this file is downloaded and placed in the data folder
# create a variable to hold the pandas DataFrame object
temperature = pd.read_csv(file, delimiter=',', skiprows=0, low_memory=False)

temperature['TempF'] = temperature['TempK'].apply(lambda x: (x - 273.15) * 9/5 + 32)

# prints the DataFrame to the screen
temperature=temperature.sort_values(by='TempK', ascending=False)


# we can combine two or more conditions in loc with the & symbol
# the & symbol between conditions indicates that both need to be satisfied for a given row

temperature.head(3)
# Out:
#       OBJECTID_1  STATEFP  COUNTYFP  GEOID    NAME     Lat      Lon  \
# 2432        2433        4        27   4027    Yuma  33.333 -114.375
# 2433        2434        4        12   4012  La Paz  33.333 -114.375
# 2087        2088        4        15   4015  Mohave  35.237 -114.375
#
#                Date_    TempK   TempF
# 2432  6/21/2016 0:00  307.700  94.190
# 2433  6/21/2016 0:00  307.700  94.190
# 2087  6/21/2016 0:00  307.325  93.515

# %%
temperature62116 = temperature.loc[(temperature["STATEFP"].isin([6 , 32 , 4]))]
                                   
temperature62116=temperature62116.sort_values(by='TempF')
temperature62116.tail(10).plot.bar(x="NAME", y="TempF", rot=90, title="61716 temperature", ylabel="Temperature Farenheit", label="LA power outages",figsize=(25, 20))
# Out:
# <AxesSubplot:title={'center':'61716 temperature'}, xlabel='NAME', ylabel='Temperature Farenheit'>

# %%
file = 'data/temperaturedata/CtyAvTemp62216.csv' # make sure this file is downloaded and placed in the data folder
# create a variable to hold the pandas DataFrame object
temperature = pd.read_csv(file, delimiter=',', skiprows=0, low_memory=False)

# prints the DataFrame to the screen
temperature['TempF'] = temperature['TempK'].apply(lambda x: (x - 273.15) * 9/5 + 32)

temperature=temperature.sort_values(by='TempK', ascending=False)


# we can combine two or more conditions in loc with the & symbol
# the & symbol between conditions indicates that both need to be satisfied for a given row

temperature.head(3)
# Out:
#       OBJECTID_1  STATEFP  COUNTYFP  GEOID    NAME     Lat      Lon    TempK  \
# 2433        2434        4        12   4012  La Paz  33.333 -114.375  305.675
# 2432        2433        4        27   4027    Yuma  33.333 -114.375  305.675
# 2733        2734        4        19   4019    Pima  31.428 -110.625  305.225
#
#        TempF
# 2433  90.545
# 2432  90.545
# 2733  89.735

# %%
temperature62216 = temperature.loc[(temperature["STATEFP"].isin([6 , 32 , 4]))]
                                   
temperature62216=temperature62216.sort_values(by='TempK')
temperature62216.tail(10).plot.bar(x="NAME", y="TempF", rot=90, title="61716 temperature", ylabel="Temperature Farenheit", label="LA power outages",figsize=(25, 20))
# Out:
# <AxesSubplot:title={'center':'61716 temperature'}, xlabel='NAME', ylabel='Temperature Farenheit'>

# %%
file = 'data/temperaturedata/CtyAvTemp62316.csv' # make sure this file is downloaded and placed in the data folder
# create a variable to hold the pandas DataFrame object
temperature = pd.read_csv(file, delimiter=',', skiprows=0, low_memory=False)

temperature['TempF'] = temperature['TempK'].apply(lambda x: (x - 273.15) * 9/5 + 32)

# prints the DataFrame to the screen
temperature=temperature.sort_values(by='TempK', ascending=False)


# we can combine two or more conditions in loc with the & symbol
# the & symbol between conditions indicates that both need to be satisfied for a given row

temperature.head(3)
# Out:
#       OBJECTID_1  STATEFP  COUNTYFP  GEOID        NAME     Lat      Lon  \
# 2733        2734        4        19   4019        Pima  31.428 -110.625
# 2734        2735        4         3   4003     Cochise  31.428 -110.625
# 2735        2736        4        23   4023  Santa Cruz  31.428 -110.625
#
#       TempK  TempF
# 2733  305.6  90.41
# 2734  305.6  90.41
# 2735  305.6  90.41

# %%
temperature62316 = temperature.loc[(temperature["STATEFP"].isin([6 , 32 , 4]))]
                                   

temperature62316=temperature62316.sort_values(by='TempK')

temperature62316.tail(10).plot.bar(x="NAME", y="TempF", rot=90, title="61716 temperature", ylabel="Temperature Farenheit", label="LA power outages",figsize=(25, 20))
# Out:
# <AxesSubplot:title={'center':'61716 temperature'}, xlabel='NAME', ylabel='Temperature Farenheit'>

# %%
file = 'data/temperaturedata/CtyAvTemp62416.csv' # make sure this file is downloaded and placed in the data folder
# create a variable to hold the pandas DataFrame object
temperature = pd.read_csv(file, delimiter=',', skiprows=0, low_memory=False)

temperature['TempF'] = temperature['TempK'].apply(lambda x: (x - 273.15) * 9/5 + 32)

# prints the DataFrame to the screen
temperature=temperature.sort_values(by='TempK', ascending=False)


# we can combine two or more conditions in loc with the & symbol
# the & symbol between conditions indicates that both need to be satisfied for a given row

temperature.head(3)
# Out:
#       OBJECTID_1  STATEFP  COUNTYFP  GEOID           NAME        Lat     Lon  \
# 2129        2130       40       149  40149        Washita  35.237499 -99.375
# 2137        2138       40        43  40043          Dewey  35.237499 -99.375
# 2130        2131       48        87  48087  Collingsworth  35.237499 -99.375
#
#         TempK   TempF
# 2129  305.625  90.455
# 2137  305.625  90.455
# 2130  305.625  90.455

# %%
temperature62416 = temperature.loc[(temperature["STATEFP"].isin([6 , 32 , 4]))]
                                   
temperature62416=temperature62416.sort_values(by='TempK')
temperature62416.tail(10).plot.bar(x="NAME", y="TempF", rot=90, title="61716 temperature", ylabel="Temperature Farenheit", label="LA power outages",figsize=(25, 20))
# Out:
# <AxesSubplot:title={'center':'61716 temperature'}, xlabel='NAME', ylabel='Temperature Farenheit'>

# %%
southeastmed
# Out:
#       FIPS_Code  County_FIPS_Code        County  State_FIPS_Code State  \
# 96         4001                 1       Apache                 4   AZ
# 97         4003                 3      Cochise                 4   AZ
# 98         4005                 5     Coconino                 4   AZ
# 99         4007                 7         Gila                 4   AZ
# 100        4009                 9       Graham                 4   AZ
# ...         ...               ...           ...              ...   ...
# 1759      32027                27     Pershing                32   NV
# 1760      32029                29       Storey                32   NV
# 1761      32031                31       Washoe                32   NV
# 1762      32033                33   White Pine                32   NV
# 1763      32510               510  Carson City                32   NV
#
#       Jan_2016_Medicare_Benes  Jan_2016_Power_Dependent_Devices_DME  \
# ...

# %%
file='data/county_population_by_year.csv'

population = pd.read_csv(file, delimiter=',', skiprows=0, low_memory=False)

#
# we can combine two or more conditions in loc with the & symbol
# the & symbol between conditions indicates that both need to be satisfied for a given row

population
# Out:
#       fips_code               name state  pop_2010  pop_2011  pop_2012  \
# 0          1001     Autauga County    AL   54773.0   55227.0   54954.0
# 1          1003     Baldwin County    AL  183112.0  186558.0  190145.0
# 2          1005     Barbour County    AL   27327.0   27341.0   27169.0
# 3          1007        Bibb County    AL   22870.0   22745.0   22667.0
# 4          1009      Blount County    AL   57376.0   57560.0   57580.0
# ...         ...                ...   ...       ...       ...       ...
# 3138      56037  Sweetwater County    WY   43574.0   43986.0   45002.0
# 3139      56039       Teton County    WY   10151.0   10161.0   10125.0
# 3140      56041       Uinta County    WY   21089.0   20896.0   20996.0
# 3141      56043    Washakie County    WY    8530.0    8449.0    8409.0
# 3142      56045      Weston County    WY    7198.0    7142.0    7077.0
#
#       pop_2013  pop_2014  pop_2015  pop_2016  pop_2017  pop_2018  pop_2019
# ...

# %%
population2016=population[['fips_code','name','state','pop_2016']]

# %%
merged_df=southeastmed.merge(population2016,how="inner", left_on="FIPS_Code", right_on="fips_code")

# %%
merged_df
# Out:
#     FIPS_Code  County_FIPS_Code        County  State_FIPS_Code State  \
# 0        4001                 1       Apache                 4   AZ
# 1        4003                 3      Cochise                 4   AZ
# 2        4005                 5     Coconino                 4   AZ
# 3        4007                 7         Gila                 4   AZ
# 4        4009                 9       Graham                 4   AZ
# ..        ...               ...           ...              ...   ...
# 85      32027                27     Pershing                32   NV
# 86      32029                29       Storey                32   NV
# 87      32031                31       Washoe                32   NV
# 88      32033                33   White Pine                32   NV
# 89      32510               510  Carson City                32   NV
#
#     Jan_2016_Medicare_Benes  Jan_2016_Power_Dependent_Devices_DME  \
# 0                      9287                                   795
# ...

# %%
medicapopjune=merged_df[['FIPS_Code','County','Jun_2016_Medicare_Benes','Jun_2016_ Power_Dependent_Devices_DME ','pop_2016']]

# %%
medical2016.columns
# Out:
# Index(['FIPS_Code', 'County_FIPS_Code', 'County', 'State_FIPS_Code', 'State',
#        'Jan_2016_Medicare_Benes', 'Jan_2016_Power_Dependent_Devices_DME',
#        'Feb_2016_Medicare_Benes', 'Feb_2016_Power_Dependent_Devices_DME',
#        'Mar_2016_Medicare_Benes', 'Mar_2016_Power_Dependent_Devices_DME',
#        'Apr_2016_Medicare_Benes', 'Apr_2016_Power_Dependent_Devices_DME',
#        'May_2016_Medicare_Benes', 'May_2016_Power_Dependent_Devices_DME',
#        'Jun_2016_Medicare_Benes', 'Jun_2016_ Power_Dependent_Devices_DME ',
#        'Jul_2016_Medicare_Benes', 'Jul_2016_Power_Dependent_Devices_DME',
#        'Aug_2016_Medicare_Benes', 'Aug_2016_Power_Dependent_Devices_DME',
#        'Sep_2016_Medicare_Benes', 'Sep_2016_Power_Dependent_Devices_DME ',
#        'Oct_2016_Medicare_Benes', 'Oct_2016_Power_Dependent_Devices_DME ',
#        'Nov_2016_Medicare_Benes', 'Nov_2016_Power_Dependent_Devices_DME ',
#        'Dec_2016_Medicare_Benes', 'Dec_2016_Power_Dependent_Devices_DME '],
# ...

# %%
medicapopjunesorted=medicapopjune.sort_values(by='Jun_2016_ Power_Dependent_Devices_DME ')

# %%
medicapopjunesorted
# Out:
#     FIPS_Code        County  Jun_2016_Medicare_Benes  \
# 16       6003       Alpine                       207
# 77      32009    Esmeralda                       223
# 86      32029       Storey                       308
# 78      32011       Eureka                       268
# 5        4011     Greenlee                      1134
# ..        ...           ...                      ...
# 47       6065    Riverside                    304973
# 51       6073    San Diego                    424598
# 74      32003        Clark                    279112
# 7        4013     Maricopa                    564618
# 33       6037  Los Angeles                   1223045
#
#     Jun_2016_ Power_Dependent_Devices_DME     pop_2016
# 16                                      20      1047.0
# 77                                      33       826.0
# 86                                      35      3986.0
# 78                                      43      1936.0
# ...

# %%
medicapopjunesorted.head(10).plot.bar(x="County", y="Jun_2016_ Power_Dependent_Devices_DME ", rot=90, title="People Depending on medical devices on june 2016", ylabel="count of medical devices", label="medical devices",figsize=(25, 20))
# Out:
# <AxesSubplot:title={'center':'People Depending on medical devices on june 2016'}, xlabel='County', ylabel='count of medical devices'>

# %%
medicapopjunesorted.tail(10).plot.bar(x="County", y="Jun_2016_ Power_Dependent_Devices_DME ", rot=90, title="People Depending on medical devices on june 2016", ylabel="count of medical devices", label="medical devices",figsize=(25, 20))
# Out:
# <AxesSubplot:title={'center':'People Depending on medical devices on june 2016'}, xlabel='County', ylabel='count of medical devices'>

# %% [markdown]
# outrages

# %% [markdown]
# #3.
# Answering the big questions!
#
# Now for the real fun! Use this notebook to work through answering the Big Questions. Apply what you learned about using Pandas and the various other tools to load the data and analyze it. Call one of the trainers or peer mentors to assist if you're stuck.
#
# Good luck!!
# The Big Questions for this Project:
#
# These are the questions you will be trying to answer using the data you have been given and the skills you developed during the bootcamp and by going through the material in the Jupyter Notebooks. Unless stated otherwise, focus on the counties in the states California, Nevada, and Arizona (but feel free to explore other states too if you're curious once your done answering the questions for those states!). Use the notebook 6_Answering_Big_Questions.ipynb to work on your answers
#
# You're free to work on any questions you find interesting (or even come up with your own questions to explore). Start on questions 1 to 4 as a good place to start and go from there!
#
# Note: whenever 'top X' is mentioned in the big questions, we're leaving it up to you to decide what number X should be.
#
#     Which counties in the Southwest US were hit with the highest average temperatures in June 17-24, 2016? Choose a subset of those days, maybe two or three. Can you show it visually, one chart for each day showing the top X counties? (Datasets: CtyAvTemp6XY16.csv where XY is 17,18,19,...,24)
#
#     Of the counties in the SW United States, for June 2016, which counties had the highest and lowest DME reliant population? What percentage of the total population of the county is that? Can you show the top X counties for each? (Datasets: 2016_HHSemPOWERMapHistoricalDataset.xlsx)
#
#     Can you show the average number of customers without power per county during the heatwave? Can you show it visually, a few charts showing some subset of days in June 17-24 showing the top X counties? (Data sets: eaglei_outages_2016.csv)
#         To show how the power outage numbers during a heatwave differ from days when there wasn't a heatwave, can you determine what the average number of customers without power per county is during a time period there wasn't a heatwave? And can you include that information in your charts?
#         Or do you think it would be better to compare outage numbers with the county population (from county_population_by_year.csv) or with number of customers from 2023 (county_customers_2023.csv). Pick whichever you think makes sense but make sure you talk about your reasoning when you present it. Remember the note that data sometimes might be missing.

# %%
merged_d3f=outrages.merge(medicapopjunesorted,how="inner", left_on="fips_code", right_on="FIPS_Code")

# %%
merged_d3f
# Out:
#         fips_code       county       state  sum       run_start_time  \
# 0            6037  Los Angeles  California   82  2016-01-01 00:00:00
# 1            6037  Los Angeles  California   82  2016-01-01 00:15:00
# 2            6037  Los Angeles  California   82  2016-01-01 00:30:00
# 3            6037  Los Angeles  California    2  2016-01-01 00:45:00
# 4            6037  Los Angeles  California    2  2016-01-01 01:00:00
# ...           ...          ...         ...  ...                  ...
# 374732       6109     Tuolumne  California   29  2016-12-11 14:15:00
# 374733       6109     Tuolumne  California   29  2016-12-11 14:30:00
# 374734       6109     Tuolumne  California   29  2016-12-11 14:45:00
# 374735       6109     Tuolumne  California   29  2016-12-11 15:00:00
# 374736       6109     Tuolumne  California   29  2016-12-11 15:15:00
#
#         FIPS_Code        County  Jun_2016_Medicare_Benes  \
# 0            6037  Los Angeles                   1223045
# ...

# %%
merged_d3f[['run_start_time']]
# Out:
#              run_start_time
# 0       2016-01-01 00:00:00
# 1       2016-01-01 00:15:00
# 2       2016-01-01 00:30:00
# 3       2016-01-01 00:45:00
# 4       2016-01-01 01:00:00
# ...                     ...
# 374732  2016-12-11 14:15:00
# 374733  2016-12-11 14:30:00
# 374734  2016-12-11 14:45:00
# 374735  2016-12-11 15:00:00
# 374736  2016-12-11 15:15:00
#
# [374737 rows x 1 columns]

# %%
heatwave=merged_d3f.loc[(merged_d3f['run_start_time'] >= "2016-06-19 00:00:00") 
                                                & (merged_d3f['run_start_time'] < "2016-06-21 00:00:00")]

# %%
heatwave
# Out:
#         fips_code       county       state   sum       run_start_time  \
# 15522        6037  Los Angeles  California  1090  2016-06-19 00:00:00
# 15523        6037  Los Angeles  California  1088  2016-06-19 00:15:00
# 15524        6037  Los Angeles  California  1149  2016-06-19 00:30:00
# 15525        6037  Los Angeles  California  1145  2016-06-19 00:45:00
# 15526        6037  Los Angeles  California  1321  2016-06-19 01:00:00
# ...           ...          ...         ...   ...                  ...
# 373368      32009    Esmeralda      Nevada     1  2016-06-20 21:30:00
# 373369      32009    Esmeralda      Nevada     1  2016-06-20 21:45:00
# 373370      32009    Esmeralda      Nevada     1  2016-06-20 22:00:00
# 373371      32009    Esmeralda      Nevada     1  2016-06-20 22:15:00
# 373372      32009    Esmeralda      Nevada     1  2016-06-20 23:00:00
#
#         FIPS_Code        County  Jun_2016_Medicare_Benes  \
# 15522        6037  Los Angeles                   1223045
# ...

# %%
grouped = heatwave.groupby(['county']).mean()

# %%
grouped
# Out:
#                 fips_code          sum  FIPS_Code  Jun_2016_Medicare_Benes  \
# county
# Carson City       32510.0     1.000000    32510.0                  11705.0
# Churchill         32001.0     1.000000    32001.0                   4764.0
# Clark             32003.0   232.573964    32003.0                 279112.0
# Douglas           32005.0    25.931034    32005.0                  12029.0
# Elko              32007.0     1.000000    32007.0                   5103.0
# Esmeralda         32009.0     1.000000    32009.0                    223.0
# Humboldt          32013.0     3.384615    32013.0                   2297.0
# Kern               6029.0     9.634146     6029.0                  98229.0
# Lander            32015.0    55.250000    32015.0                    732.0
# Los Angeles        6037.0  2404.951872     6037.0                1223045.0
# Lyon              32019.0     1.337209    32019.0                  11932.0
# ...

# %%
grouped=grouped.reset_index()

# %%
grouped
# Out:
#             county  fips_code          sum  FIPS_Code  \
# 0      Carson City    32510.0     1.000000    32510.0
# 1        Churchill    32001.0     1.000000    32001.0
# 2            Clark    32003.0   232.573964    32003.0
# 3          Douglas    32005.0    25.931034    32005.0
# 4             Elko    32007.0     1.000000    32007.0
# 5        Esmeralda    32009.0     1.000000    32009.0
# 6         Humboldt    32013.0     3.384615    32013.0
# 7             Kern     6029.0     9.634146     6029.0
# 8           Lander    32015.0    55.250000    32015.0
# 9      Los Angeles     6037.0  2404.951872     6037.0
# 10            Lyon    32019.0     1.337209    32019.0
# 11        Maricopa     4013.0   224.488764     4013.0
# 12          Orange     6059.0  1712.181287     6059.0
# 13            Pima     4019.0   213.500000     4019.0
# 14           Pinal     4021.0    11.142857     4021.0
# 15       Riverside     6065.0   576.104651     6065.0
# ...

# %%
grouped=grouped.sort_values(by='sum')
plt.rcParams.update({'font.size': 30})
grouped.tail(10).plot.bar(x="county", y="sum", rot=90, title="Top 10 counties Average number of outages", ylabel="average of outages", label="outages",figsize=(25, 20))
# Out:
# <AxesSubplot:title={'center':'Top 10 counties Average number of outages'}, xlabel='county', ylabel='average of outages'>

# %%
heatwave=merged_d3f.loc[(merged_d3f['run_start_time'] >= "2016-06-01 00:00:00") 
                                                & (merged_d3f['run_start_time'] < "2016-06-15 00:00:00")]

# %%
grouped2 = heatwave.groupby(['county']).mean()
grouped2=grouped2.reset_index()

grouped2=grouped2.sort_values(by='sum')

grouped2.tail(10).plot.bar(x="county", y="sum", rot=90, title="Top 10 counties Average number of outages", ylabel="average of outages", label="outages",figsize=(25, 20))
plt.text(6, 30, 'some text', weight='bold')
# Out:
# Text(6, 30, 'some text')

# %%
grouped2=grouped2.rename(columns={"sum": "sumNoHeat"})

# %%
grouped2
# Out:
#             county  fips_code    sumNoHeat  FIPS_Code  \
# 21        Pershing    32027.0     1.261538    32027.0
# 6           Eureka    32011.0     1.942857    32011.0
# 12          Lander    32015.0     2.852071    32015.0
# 14            Lyon    32019.0     3.781513    32019.0
# 28     Santa Clara     6085.0     5.863874     6085.0
# 5        Esmeralda    32009.0     6.625000    32009.0
# 19             Nye    32023.0     7.190476    32023.0
# 16         Mineral    32021.0     7.493827    32021.0
# 7           Fresno     6019.0    10.000000     6019.0
# 3          Douglas    32005.0    17.285088    32005.0
# 1        Churchill    32001.0    21.375940    32001.0
# 30          Storey    32029.0    23.076923    32029.0
# 23           Pinal     4021.0    23.584229     4021.0
# 9             Inyo     6027.0    23.887097     6027.0
# 34            Yuma     4027.0    25.000000     4027.0
# 8         Humboldt    32013.0    29.870079    32013.0
# ...

# %%
mergegroup=grouped.merge(grouped2,how="inner", left_on="county", right_on="county")

# %%
mergegroup
# Out:
#             county  fips_code_x          sum  FIPS_Code_x  \
# 0      Carson City      32510.0     1.000000      32510.0
# 1        Churchill      32001.0     1.000000      32001.0
# 2           Storey      32029.0     1.000000      32029.0
# 3             Elko      32007.0     1.000000      32007.0
# 4        Esmeralda      32009.0     1.000000      32009.0
# 5             Lyon      32019.0     1.337209      32019.0
# 6         Humboldt      32013.0     3.384615      32013.0
# 7             Kern       6029.0     9.634146       6029.0
# 8            Pinal       4021.0    11.142857       4021.0
# 9    Santa Barbara       6083.0    22.267380       6083.0
# 10         Douglas      32005.0    25.931034      32005.0
# 11          Washoe      32031.0    38.087912      32031.0
# 12          Lander      32015.0    55.250000      32015.0
# 13          Tulare       6107.0   150.225806       6107.0
# 14            Pima       4019.0   213.500000       4019.0
# ...

# %%
mergegroup=mergegroup.sort_values(by='sum')

#mergegroup.tail(10).plot.bar(x="county", y="sum", rot=90, title="Top 10 counties Average number of outages", ylabel="average of outages", label="outages",figsize=(25, 20))

colors = {'sum':'red', 'sumNoHeat':'blue'}
#plot = df_med_temp.plot(x='Jun_2016_ Power_Dependent_Devices_DME ', y='TempF', kind='bar',color=colors, figsize=(15, 5), title='med vs tem');
colors_list = [colors[col] for col in mergegroup.columns if col in colors]
plot = mergegroup.tail(10).plot(x='county', y=['sum','sumNoHeat'], 
                        kind='bar',
                        color=colors_list,
                        title='Heatwave Vs No Heatwave', figsize=(25, 20), xlabel='Counties',ylabel='Average number of outages')
plt.legend(['Heatwave', 'No Heatwave'])

# %%
heatwave
# Out:
#         fips_code       county       state   sum       run_start_time  \
# 13853        6037  Los Angeles  California  1766  2016-06-01 00:00:00
# 13854        6037  Los Angeles  California  1684  2016-06-01 00:15:00
# 13855        6037  Los Angeles  California  1575  2016-06-01 00:30:00
# 13856        6037  Los Angeles  California  1544  2016-06-01 00:45:00
# 13857        6037  Los Angeles  California  1281  2016-06-01 01:00:00
# ...           ...          ...         ...   ...                  ...
# 374293       4023   Santa Cruz     Arizona     9  2016-06-10 02:45:00
# 374294       4023   Santa Cruz     Arizona     9  2016-06-10 03:00:00
# 374295       4023   Santa Cruz     Arizona     9  2016-06-10 03:15:00
# 374296       4023   Santa Cruz     Arizona     9  2016-06-10 03:30:00
# 374583       4027         Yuma     Arizona    25  2016-06-13 00:45:00
#
#         FIPS_Code        County  Jun_2016_Medicare_Benes  \
# 13853        6037  Los Angeles                   1223045
# ...

# %%
plt.scatter(grouped['Jun_2016_ Power_Dependent_Devices_DME '], grouped['sum'])

plt.ylabel('devices');
plt.xlabel('outrages');

# %%
import scipy.stats
from scipy.stats import spearmanr
corr3 = scipy.stats.spearmanr(grouped['Jun_2016_ Power_Dependent_Devices_DME '], grouped['sum'])
corr3
# Out:
# SpearmanrResult(correlation=0.8270821216802181, pvalue=6.248925824262407e-07)

# %%
medical2016
# Out:
#       FIPS_Code  County_FIPS_Code         County  State_FIPS_Code State  \
# 0          1001                 1       Autauga                 1   AL
# 1          1003                 3       Baldwin                 1   AL
# 2          1005                 5       Barbour                 1   AL
# 3          1007                 7          Bibb                 1   AL
# 4          1009                 9        Blount                 1   AL
# ...         ...               ...            ...              ...   ...
# 3223      72151               151       Yabucoa                72   PR
# 3224      72153               153         Yauco                72   PR
# 3225      78010                10   Saint Croix                78   VI
# 3226      78020                20    Saint John                78   VI
# 3227      78030                30  Saint Thomas                78   VI
#
#       Jan_2016_Medicare_Benes  Jan_2016_Power_Dependent_Devices_DME  \
# ...

# %%
file = 'data/CtyAvDemog2010.csv'
atsm = pd.read_csv(file, delimiter=',', skiprows=0, low_memory=False)

# prints the DataFrame to the screen
atsm
# Out:
#       OBJECTID  STATEFP  COUNTYFP  GEOID       NAME        Lat         Lon  \
# 0            1       31        39  31039     Cuming  41.915865  -96.788517
# 1            2       53        69  53069  Wahkiakum  46.294638 -123.424458
# 2            3       35        11  35011    De Baca  34.359273 -104.368696
# 3            4       31       109  31109  Lancaster  40.783547  -96.688658
# 4            5       31       129  31129   Nuckolls  40.176492  -98.046842
# ...        ...      ...       ...    ...        ...        ...         ...
# 3228      3229       13       123  13123     Gilmer  34.690506  -84.454624
# 3229      3230       27       135  27135     Roseau  48.761068  -95.821504
# 3230      3231       28        89  28089    Madison  32.634370  -90.034160
# 3231      3232       48       227  48227     Howard  32.303471 -101.438772
# 3232      3233       54        99  54099      Wayne  38.143642  -82.422666
#
#       Avg_PercentBlackorAfricanAmericanalone  \
# ...

# %%
#asthmatic corelation between it and medical dependant

# %%
atsm.columns
# Out:
# Index(['OBJECTID', 'STATEFP', 'COUNTYFP', 'GEOID', 'NAME', 'Lat', 'Lon',
#        'Avg_PercentBlackorAfricanAmericanalone',
#        'Avg_PercentAmericanIndian_AlaskaNative', 'Avg_PercentAsian',
#        'Avg_PercentNativeHawaiianPacific', 'Avg_PercentTwoOrMoreRaces',
#        'Avg_PercentWhite', 'Avg_PercentHispanicLatino',
#        'Avg_PercentOtherRaces', 'Avg_PercentAgeUnder10',
#        'Avg_PercentAge10To64', 'Avg_PercentAgeOver64',
#        'Avg_TotalThresholdCriteriaExceeded', 'Avg_TotalCategoriesExceeded',
#        'Avg_PercentageOfTractThatIsDisadvantagedByArea',
#        'Avg_ShareOfNeighborsThatAreIdentifiedAsDisadvantaged',
#        'Avg_TotalPopulation',
#        'Avg_AdjustedPercentOfIndividualsBelow200pctFederalPovertyLine',
#        'Avg_AdjustedPercentOfIndividualsBelow200pctFederalPovertyLine_1',
#        'Avg_ExpectedAgriculturalLossRatePct',
#        'Avg_ExpectedAgriculturalLossRateIndex',
# ...

# %%
atsm['Avg_CurrentAsthmaAmongAdultsAgedGreaterThanOrEqualTo18Years']
# Out:
# 0        820.000000
# 1       1040.000000
# 2        969.000000
# 3        879.270270
# 4        835.000000
#            ...
# 3228     947.600000
# 3229     894.000000
# 3230     925.619048
# 3231     886.000000
# 3232    1155.454545
# Name: Avg_CurrentAsthmaAmongAdultsAgedGreaterThanOrEqualTo18Years, Length: 3233, dtype: float64

# %%
mergedmed=atsm.merge(medical2016,how="inner", left_on="COUNTYFP", right_on="County_FIPS_Code")

# %%
mergedmed
# Out:
#        OBJECTID  STATEFP  COUNTYFP  GEOID              NAME        Lat  \
# 0             1       31        39  31039            Cuming  41.915865
# 1             1       31        39  31039            Cuming  41.915865
# 2             1       31        39  31039            Cuming  41.915865
# 3             1       31        39  31039            Cuming  41.915865
# 4             1       31        39  31039            Cuming  41.915865
# ...         ...      ...       ...    ...               ...        ...
# 98406      3173       51       570  51570  Colonial Heights  37.261685
# 98407      3183       48       505  48505            Zapata  26.996981
# 98408      3191       51       810  51810    Virginia Beach  36.779985
# 98409      3197        2       230   2230           Skagway  59.560379
# 98410      3202       48       453  48453            Travis  30.239513
#
#               Lon  Avg_PercentBlackorAfricanAmericanalone  \
# ...

# %%
corr3 = scipy.stats.spearmanr(mergedmed['Jun_2016_ Power_Dependent_Devices_DME '], mergedmed['Avg_CurrentAsthmaAmongAdultsAgedGreaterThanOrEqualTo18Years'])
corr3
# Out:
# SpearmanrResult(correlation=0.0019119596023565485, pvalue=0.5486497020725254)

# %%
file='data/hourlytemp2016.csv'
hourly = pd.read_csv(file, delimiter=',', skiprows=0, low_memory=False)

# prints the DataFrame to the screen
hourly
# Out:
#     CountyFP                    time  TempF
# 0     6037.0            6/20/16 0:45   73.0
# 1     6037.0            6/20/16 1:45   74.0
# 2     6037.0            6/20/16 2:45   78.0
# 3     6037.0            6/20/16 3:45   72.0
# 4     6037.0            6/20/16 4:45   72.0
# 5     6037.0            6/20/16 5:45   72.0
# 6     6037.0            6/20/16 6:45   75.0
# 7     6037.0            6/20/16 7:45   83.0
# 8     6037.0            6/20/16 8:45   94.0
# 9     6037.0   2016-06-20 9:45:00 AM   98.0
# 10    6037.0           6/20/16 10:45   95.0
# 11    6037.0           6/20/16 11:45   95.0
# 12    6037.0           6/20/16 12:45   94.0
# 13    6037.0           6/20/16 13:45   95.0
# 14    6037.0           6/20/16 14:45   97.0
# 15    6037.0           6/20/16 15:45   98.0
# 16    6037.0           6/20/16 16:45   98.0
# 17    6037.0           6/20/16 17:45   98.0
# 18    6037.0           6/20/16 18:45   96.0
# 19    6037.0           6/20/16 19:45   87.0
# ...

# %%
#hourly.at[9,'time']='9:45 AM'

# %%
hourly
# Out:
#     CountyFP                    time  TempF
# 0     6037.0            6/20/16 0:45   73.0
# 1     6037.0            6/20/16 1:45   74.0
# 2     6037.0            6/20/16 2:45   78.0
# 3     6037.0            6/20/16 3:45   72.0
# 4     6037.0            6/20/16 4:45   72.0
# 5     6037.0            6/20/16 5:45   72.0
# 6     6037.0            6/20/16 6:45   75.0
# 7     6037.0            6/20/16 7:45   83.0
# 8     6037.0            6/20/16 8:45   94.0
# 9     6037.0   2016-06-20 9:45:00 AM   98.0
# 10    6037.0           6/20/16 10:45   95.0
# 11    6037.0           6/20/16 11:45   95.0
# 12    6037.0           6/20/16 12:45   94.0
# 13    6037.0           6/20/16 13:45   95.0
# 14    6037.0           6/20/16 14:45   97.0
# 15    6037.0           6/20/16 15:45   98.0
# 16    6037.0           6/20/16 16:45   98.0
# 17    6037.0           6/20/16 17:45   98.0
# 18    6037.0           6/20/16 18:45   96.0
# 19    6037.0           6/20/16 19:45   87.0
# ...

# %%
outrages
# Out:
#           fips_code           county          state  sum       run_start_time
# 0              2122  Kenai Peninsula         Alaska  657  2016-01-01 00:00:00
# 1              5003           Ashley       Arkansas    7  2016-01-01 00:00:00
# 2              5029           Conway       Arkansas    2  2016-01-01 00:00:00
# 3              5069        Jefferson       Arkansas   41  2016-01-01 00:00:00
# 4              5081     Little River       Arkansas   61  2016-01-01 00:00:00
# ...             ...              ...            ...  ...                  ...
# 13306019      54061       Monongalia  West Virginia  472  2016-12-31 00:00:00
# 13306020      54069             Ohio  West Virginia   37  2016-12-31 00:00:00
# 13306021      54075       Pocahontas  West Virginia  200  2016-12-31 00:00:00
# 13306022      54099            Wayne  West Virginia    2  2016-12-31 00:00:00
# 13306023      55103         Richland      Wisconsin    1  2016-12-31 00:00:00
#
# [13306024 rows x 5 columns]

# %%
out=outrages.loc[(outrages['run_start_time'] >= "2016-06-20 00:00:00") 
                                                & (outrages['run_start_time'] < "2016-06-21 00:00:00")]

# %%
out
# Out:
#          fips_code        county         state   sum       run_start_time
# 5966141       4013      Maricopa       Arizona   754  2016-06-20 00:00:00
# 5966142       4019          Pima       Arizona  1027  2016-06-20 00:00:00
# 5966143       5003        Ashley      Arkansas    54  2016-06-20 00:00:00
# 5966144       5045      Faulkner      Arkansas     2  2016-06-20 00:00:00
# 5966145       5093   Mississippi      Arkansas     2  2016-06-20 00:00:00
# ...            ...           ...           ...   ...                  ...
# 6010320      42045      Delaware  Pennsylvania    29  2016-06-20 23:45:00
# 6010321      42091    Montgomery  Pennsylvania     8  2016-06-20 23:45:00
# 6010322      42101  Philadelphia  Pennsylvania    47  2016-06-20 23:45:00
# 6010323      48029         Bexar         Texas    12  2016-06-20 23:45:00
# 6010324      48325        Medina         Texas     1  2016-06-20 23:45:00
#
# [44184 rows x 5 columns]

# %%
out=outrages.loc[(outrages['fips_code']==6037 )]

# %%
out
# Out:
#           fips_code       county       state  sum       run_start_time
# 8              6037  Los Angeles  California   82  2016-01-01 00:00:00
# 342            6037  Los Angeles  California   82  2016-01-01 00:15:00
# 671            6037  Los Angeles  California   82  2016-01-01 00:30:00
# 993            6037  Los Angeles  California    2  2016-01-01 00:45:00
# 1315           6037  Los Angeles  California    2  2016-01-01 01:00:00
# ...             ...          ...         ...  ...                  ...
# 13304515       6037  Los Angeles  California  193  2016-12-30 23:00:00
# 13304832       6037  Los Angeles  California  182  2016-12-30 23:15:00
# 13305145       6037  Los Angeles  California  206  2016-12-30 23:30:00
# 13305437       6037  Los Angeles  California  216  2016-12-30 23:45:00
# 13305739       6037  Los Angeles  California  216  2016-12-31 00:00:00
#
# [33399 rows x 5 columns]

# %%
hourly['time'] = hourly['time'].apply(lambda time : pd.to_datetime(time).value)

# %%
hourly
# Out:
#     CountyFP                 time  TempF
# 0     6037.0  1466383500000000000   73.0
# 1     6037.0  1466387100000000000   74.0
# 2     6037.0  1466390700000000000   78.0
# 3     6037.0  1466394300000000000   72.0
# 4     6037.0  1466397900000000000   72.0
# 5     6037.0  1466401500000000000   72.0
# 6     6037.0  1466405100000000000   75.0
# 7     6037.0  1466408700000000000   83.0
# 8     6037.0  1466412300000000000   94.0
# 9     6037.0  1466415900000000000   98.0
# 10    6037.0  1466419500000000000   95.0
# 11    6037.0  1466423100000000000   95.0
# 12    6037.0  1466426700000000000   94.0
# 13    6037.0  1466430300000000000   95.0
# 14    6037.0  1466433900000000000   97.0
# 15    6037.0  1466437500000000000   98.0
# 16    6037.0  1466441100000000000   98.0
# 17    6037.0  1466444700000000000   98.0
# 18    6037.0  1466448300000000000   96.0
# 19    6037.0  1466451900000000000   87.0
# 20    6037.0  1466455500000000000   83.0
# 21    6037.0  1466459100000000000   76.0
# ...

# %%
out['run_start_time'] = out['run_start_time'].apply(lambda run_start_time : pd.to_datetime(run_start_time).value)
out
# Out:
# /tmp/ipykernel_1644987/3689923224.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   out['run_start_time'] = out['run_start_time'].apply(lambda run_start_time : pd.to_datetime(run_start_time).value)
#           fips_code       county       state  sum       run_start_time
# 8              6037  Los Angeles  California   82  1451606400000000000
# 342            6037  Los Angeles  California   82  1451607300000000000
# 671            6037  Los Angeles  California   82  1451608200000000000
# 993            6037  Los Angeles  California    2  1451609100000000000
# 1315           6037  Los Angeles  California    2  1451610000000000000
# ...             ...          ...         ...  ...                  ...
# ...

# %%
timemerge=hourly.merge(out,how="inner", left_on="time", right_on="run_start_time")

# %%
timemerge
# Out:
#     CountyFP                 time  TempF  fips_code       county       state  \
# 0     6037.0  1466383500000000000   73.0       6037  Los Angeles  California
# 1     6037.0  1466387100000000000   74.0       6037  Los Angeles  California
# 2     6037.0  1466390700000000000   78.0       6037  Los Angeles  California
# 3     6037.0  1466394300000000000   72.0       6037  Los Angeles  California
# 4     6037.0  1466397900000000000   72.0       6037  Los Angeles  California
# 5     6037.0  1466401500000000000   72.0       6037  Los Angeles  California
# 6     6037.0  1466405100000000000   75.0       6037  Los Angeles  California
# 7     6037.0  1466408700000000000   83.0       6037  Los Angeles  California
# 8     6037.0  1466412300000000000   94.0       6037  Los Angeles  California
# 9     6037.0  1466415900000000000   98.0       6037  Los Angeles  California
# 10    6037.0  1466419500000000000   95.0       6037  Los Angeles  California
# ...

# %%
corr3 = scipy.stats.spearmanr(timemerge['TempF'], timemerge['sum'])
corr3
# Out:
# SpearmanrResult(correlation=-0.3058834651737724, pvalue=0.16622921468694518)

# %%
timemerge.plot.bar(x="TempF", y="sum", rot=90, title="Top 10 counties Average number of outages", ylabel="average of outages", label="outages",figsize=(25, 20))
plt.text(6, 30, 'some text', weight='bold')
# Out:
# Text(6, 30, 'some text')

# %%
import geopandas

# %%
ctyavtemp61916_gdf = gpd.GeoDataFrame(temperature61916, geometry=gpd.points_from_xy(temperature61916['Lon'], temperature61916['Lat'], crs="EPSG:4326"))
ctyavtemp61916_gdf
# Out:
#       OBJECTID_1  STATEFP  COUNTYFP  GEOID       NAME        Lat         Lon  \
# 208         1188        6        45   6045  Mendocino  39.432388 -123.442881
# 234         1187        6        97   6097     Sonoma  38.525182 -122.926109
# 1761         785       32        31  32031     Washoe  40.734015 -119.662272
# 210          784        6        49   6049      Modoc  41.592919 -120.718370
# 203          783        6        35   6035     Lassen  40.721086 -120.629952
# ...          ...      ...       ...    ...        ...        ...         ...
# 106         2734        4        19   4019       Pima  32.128043 -111.783657
# 97          2735        4         3   4003    Cochise  31.840129 -109.775163
# 103         2435        4        13   4013   Maricopa  33.345176 -112.498930
# 102         2434        4        12   4012     La Paz  33.727610 -114.038806
# 110         2433        4        27   4027       Yuma  32.773942 -113.910905
#
# ...

# %%
ctyavtemp61916_gdf.plot(column='TempF', cmap='YlOrRd', legend=True, figsize=(15, 5))
# Out:
# <AxesSubplot:>

# %%
import numpy as np
uscounties_polygons_gdf = gpd.read_file('https://raw.githubusercontent.com/holtzy/The-Python-Graph-Gallery/master/static/data/US-counties.geojson')
uscounties_polygons_gdf["id"] = uscounties_polygons_gdf["id"].astype(str).astype(np.int64)
uscounties_polygons_gdf = uscounties_polygons_gdf.rename(columns={"id":"FIPS_Code"})
uscounties_polygons_gdf
# Out:
#       FIPS_Code          GEO_ID STATE COUNTY          NAME    LSAD  \
# 0          1001  0500000US01001    01    001       Autauga  County
# 1          1009  0500000US01009    01    009        Blount  County
# 2          1017  0500000US01017    01    017      Chambers  County
# 3          1021  0500000US01021    01    021       Chilton  County
# 4          1033  0500000US01033    01    033       Colbert  County
# ...         ...             ...   ...    ...           ...     ...
# 3216      51001  0500000US51001    51    001      Accomack  County
# 3217      51021  0500000US51021    51    021         Bland  County
# 3218      51027  0500000US51027    51    027      Buchanan  County
# 3219      51037  0500000US51037    51    037     Charlotte  County
# 3220      51041  0500000US51041    51    041  Chesterfield  County
#
#       CENSUSAREA                                           geometry
# 0        594.436  POLYGON ((-86.49677 32.34444, -86.71790 32.402...
# ...

# %%
uscounties_polygons_gdf.plot(color="white", edgecolor="black",figsize=(50,50))
# Out:
# <AxesSubplot:>

# %%
uscounties_temp_gdf = uscounties_polygons_gdf.sjoin(ctyavtemp61916_gdf, how='inner', predicate="contains")

# %%
uscounties_temp_gdf
# Out:
#       FIPS_Code          GEO_ID STATE COUNTY    NAME_left    LSAD  CENSUSAREA  \
# 23         6005  0500000US06005    06    005       Amador  County     594.583
# 24         6021  0500000US06021    06    021        Glenn  County    1313.947
# 25         6033  0500000US06033    06    033         Lake  County    1256.464
# 26         6043  0500000US06043    06    043     Mariposa  County    1448.816
# 27         6055  0500000US06055    06    055         Napa  County     748.362
# ...         ...             ...   ...    ...          ...     ...         ...
# 2736      32015  0500000US32015    32    015       Lander  County    5490.105
# 2737      32019  0500000US32019    32    019         Lyon  County    2001.187
# 2738      32029  0500000US32029    32    029       Storey  County     262.920
# 2966       4025  0500000US04025    04    025      Yavapai  County    8123.499
# 3141       6085  0500000US06085    06    085  Santa Clara  County    1290.100
#
# ...

# %%
import folium
county_map = uscounties_temp_gdf.explore(column="TempF", tooltip=["NAME_left", "TempF"], name="farenheit")
uscounties_temp_gdf.explore( m=county_map, column="STATE", tooltip=["NAME_left", "STATE",'TempF'], name="state")
folium.LayerControl().add_to(county_map)

county_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
temperature61916
# Out:
#       OBJECTID_1  STATEFP  COUNTYFP  GEOID       NAME        Lat         Lon  \
# 208         1188        6        45   6045  Mendocino  39.432388 -123.442881
# 234         1187        6        97   6097     Sonoma  38.525182 -122.926109
# 1761         785       32        31  32031     Washoe  40.734015 -119.662272
# 210          784        6        49   6049      Modoc  41.592919 -120.718370
# 203          783        6        35   6035     Lassen  40.721086 -120.629952
# ...          ...      ...       ...    ...        ...        ...         ...
# 106         2734        4        19   4019       Pima  32.128043 -111.783657
# 97          2735        4         3   4003    Cochise  31.840129 -109.775163
# 103         2435        4        13   4013   Maricopa  33.345176 -112.498930
# 102         2434        4        12   4012     La Paz  33.727610 -114.038806
# 110         2433        4        27   4027       Yuma  32.773942 -113.910905
#
#                Date_       TempK      TempF
# ...

# %%
heatwaveDay19=merged_d3f.loc[(merged_d3f['run_start_time'] >= "2016-06-19 00:00:00") 
                                                & (merged_d3f['run_start_time'] < "2016-06-20 00:00:00")]

# %%
heatwaveDay19
# Out:
#         fips_code       county       state   sum       run_start_time  \
# 15522        6037  Los Angeles  California  1090  2016-06-19 00:00:00
# 15523        6037  Los Angeles  California  1088  2016-06-19 00:15:00
# 15524        6037  Los Angeles  California  1149  2016-06-19 00:30:00
# 15525        6037  Los Angeles  California  1145  2016-06-19 00:45:00
# 15526        6037  Los Angeles  California  1321  2016-06-19 01:00:00
# ...           ...          ...         ...   ...                  ...
# 373277      32009    Esmeralda      Nevada     1  2016-06-19 22:45:00
# 373278      32009    Esmeralda      Nevada     1  2016-06-19 23:00:00
# 373279      32009    Esmeralda      Nevada     1  2016-06-19 23:15:00
# 373280      32009    Esmeralda      Nevada     1  2016-06-19 23:30:00
# 373281      32009    Esmeralda      Nevada     1  2016-06-19 23:45:00
#
#         FIPS_Code        County  Jun_2016_Medicare_Benes  \
# 15522        6037  Los Angeles                   1223045
# ...

# %%
mergedday19=heatwaveDay19.merge(temperature61916 ,how="inner", left_on="FIPS_Code", right_on="GEOID")

# %%
mergedday19
# Out:
#      fips_code       county       state   sum       run_start_time  FIPS_Code  \
# 0         6037  Los Angeles  California  1090  2016-06-19 00:00:00       6037
# 1         6037  Los Angeles  California  1088  2016-06-19 00:15:00       6037
# 2         6037  Los Angeles  California  1149  2016-06-19 00:30:00       6037
# 3         6037  Los Angeles  California  1145  2016-06-19 00:45:00       6037
# 4         6037  Los Angeles  California  1321  2016-06-19 01:00:00       6037
# ..         ...          ...         ...   ...                  ...        ...
# 986      32009    Esmeralda      Nevada     1  2016-06-19 22:45:00      32009
# 987      32009    Esmeralda      Nevada     1  2016-06-19 23:00:00      32009
# 988      32009    Esmeralda      Nevada     1  2016-06-19 23:15:00      32009
# 989      32009    Esmeralda      Nevada     1  2016-06-19 23:30:00      32009
# 990      32009    Esmeralda      Nevada     1  2016-06-19 23:45:00      32009
#
# ...

# %%
ctyavtemp61916_gdf = gpd.GeoDataFrame(mergedday19, geometry=gpd.points_from_xy(mergedday19['Lon'], mergedday19['Lat'], crs="EPSG:4326"))
ctyavtemp61916_gdf
# Out:
#      fips_code       county       state   sum       run_start_time  FIPS_Code  \
# 0         6037  Los Angeles  California  1090  2016-06-19 00:00:00       6037
# 1         6037  Los Angeles  California  1088  2016-06-19 00:15:00       6037
# 2         6037  Los Angeles  California  1149  2016-06-19 00:30:00       6037
# 3         6037  Los Angeles  California  1145  2016-06-19 00:45:00       6037
# 4         6037  Los Angeles  California  1321  2016-06-19 01:00:00       6037
# ..         ...          ...         ...   ...                  ...        ...
# 986      32009    Esmeralda      Nevada     1  2016-06-19 22:45:00      32009
# 987      32009    Esmeralda      Nevada     1  2016-06-19 23:00:00      32009
# 988      32009    Esmeralda      Nevada     1  2016-06-19 23:15:00      32009
# 989      32009    Esmeralda      Nevada     1  2016-06-19 23:30:00      32009
# 990      32009    Esmeralda      Nevada     1  2016-06-19 23:45:00      32009
#
# ...

# %%
uscounties_polygons_gdf = gpd.read_file('https://raw.githubusercontent.com/holtzy/The-Python-Graph-Gallery/master/static/data/US-counties.geojson')
uscounties_polygons_gdf["id"] = uscounties_polygons_gdf["id"].astype(str).astype(np.int64)
uscounties_polygons_gdf = uscounties_polygons_gdf.rename(columns={"id":"FIPS_Code"})
uscounties_polygons_gdf
# Out:
#       FIPS_Code          GEO_ID STATE COUNTY          NAME    LSAD  \
# 0          1001  0500000US01001    01    001       Autauga  County
# 1          1009  0500000US01009    01    009        Blount  County
# 2          1017  0500000US01017    01    017      Chambers  County
# 3          1021  0500000US01021    01    021       Chilton  County
# 4          1033  0500000US01033    01    033       Colbert  County
# ...         ...             ...   ...    ...           ...     ...
# 3216      51001  0500000US51001    51    001      Accomack  County
# 3217      51021  0500000US51021    51    021         Bland  County
# 3218      51027  0500000US51027    51    027      Buchanan  County
# 3219      51037  0500000US51037    51    037     Charlotte  County
# 3220      51041  0500000US51041    51    041  Chesterfield  County
#
#       CENSUSAREA                                           geometry
# 0        594.436  POLYGON ((-86.49677 32.34444, -86.71790 32.402...
# ...

# %%
uscounties_temp_gdf = uscounties_polygons_gdf.sjoin(ctyavtemp61916_gdf, how='inner', predicate="contains")

# %%
uscounties_temp_gdf
# Out:
#       FIPS_Code_left          GEO_ID STATE COUNTY NAME_left    LSAD  \
# 76              4013  0500000US04013    04    013  Maricopa  County
# 76              4013  0500000US04013    04    013  Maricopa  County
# 76              4013  0500000US04013    04    013  Maricopa  County
# 76              4013  0500000US04013    04    013  Maricopa  County
# 76              4013  0500000US04013    04    013  Maricopa  County
# ...              ...             ...   ...    ...       ...     ...
# 2737           32019  0500000US32019    32    019      Lyon  County
# 2737           32019  0500000US32019    32    019      Lyon  County
# 2737           32019  0500000US32019    32    019      Lyon  County
# 2738           32029  0500000US32029    32    029    Storey  County
# 2738           32029  0500000US32029    32    029    Storey  County
#
#       CENSUSAREA                                           geometry  \
# 76      9200.143  POLYGON ((-111.58063 33.46590, -111.58305 33.2...
# ...

# %%
county_map = uscounties_temp_gdf.explore(column="TempF", tooltip=["NAME_left", "TempF"], name="farenheit")
uscounties_temp_gdf.explore( m=county_map, column="STATE", tooltip=["NAME_left", "STATE",'TempF'], name="state")
folium.LayerControl().add_to(county_map)

county_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...
