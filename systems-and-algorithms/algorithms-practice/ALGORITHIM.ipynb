# %%
import numpy as np

# %%
def partition(A,p,r):
    if 1:
        x=A[r]
        i= p -1
        for j in range(p,r):
            if A[j]%2 ==0:
                i=i+1
                vali=A[i]
                valj=A[j]
                A[i]=valj
                A[j]=vali
            y=A[i+1]
            A[i+1] = x
            A[r]=y
    return A

# %%
def partition(A,p,r):
    if 1:
        x=A[r]
        i= p -1
        for j in range(p,r):
            if A[j]%2 ==0:
                i=i+1
                vali=A[i]
                valj=A[j]
                A[i]=valj
                A[j]=vali
        y=A[i+1]
        A[i+1] = x
        A[r]=y
    return A

# %%
ran=np.random.randint(1,1000,1000)
ran
# Out:
# array([564,  17, 186, 690, 662,  97, 667,  61, 816, 718, 160, 568, 192,
#        641, 473, 944, 832, 885, 495, 980, 713,  22, 533, 494, 979, 830,
#        770, 680, 962, 570, 357, 751, 531, 433, 131, 798, 688, 770, 873,
#        888, 457, 509, 182, 483, 933, 455, 482, 733,  12, 125, 751, 645,
#        310, 534, 214, 866,  45, 335, 479, 135, 572, 337, 462, 834,  52,
#        390, 720, 550, 552, 152, 875, 356, 264, 447, 593, 895, 369, 297,
#        693, 472, 944, 718, 390, 544, 680, 231, 905, 419, 657, 186, 396,
#        912, 977, 684, 341, 645, 189, 413,  15, 115, 270, 117, 189, 108,
#        838, 380, 322,  62, 803, 851, 255, 693, 184,  88, 763, 642, 633,
#        538, 835, 221, 449, 778, 663, 645, 680, 398, 383, 267, 630, 165,
#        415, 493, 367, 796, 494, 793, 696, 798,  16, 816, 980, 626, 139,
#        884, 999, 116, 682, 591, 417, 410, 533,  90, 480,  60, 103,  91,
#        435, 291, 906, 444, 963, 992, 683, 824, 310, 940, 983, 901, 828,
# ...

# %%
print(partition(ran,0,len(ran)-1))
# Out:
# [564 186 690 662 816 718 160 568 192 944 832 980  22 494 830 770 680 962
#  570 798 688 770 888 182 482  12 310 534 214 866 572 462 834  52 390 720
#  550 552 152 356 264 472 944 718 390 544 680 186 396 912 684 270 108 838
#  380 322  62 184  88 642 538 778 680 398 630 796 494 696 798  16 816 980
#  626 884 116 682 410  90 480  60 906 444 992 824 310 940 828 750 318  96
#  584  82 684 584 384 698 886 748 706 616 152 626 602 788 292 510 478 664
#  180 400 466 890 370 676 422 594 148 956 602 482 308 178 230 634 558 172
#  410 990 658 948 420 838 156 314 678 762 408 492  76 790 942 212  40 412
#   96 670 992 182 662 668 250 522 682 854 498 356 730 848 350 148 988 428
#  824 496 822 102 914 572 962  52 254 804 886 946 610 550 864 412 262 158
#   14 550 746 832 674 750  80 362 608  42 566  52 462  50 228 744 128 334
#  458 366 104 748 590 850 284 614 504 280 608 294 144 174 288  48 540 922
#   38 432  68 678 356  54 400 220 896 258 680  94 196 504 354 212  68 734
# ...

# %%
import random

# %%
ran = random.sample(range(100),100)

# %%
print(ran)
# Out:
# [21, 25, 99, 34, 57, 89, 94, 78, 32, 98, 90, 5, 92, 0, 53, 58, 13, 17, 88, 65, 46, 45, 19, 39, 66, 7, 56, 91, 55, 79, 31, 26, 16, 74, 49, 62, 8, 6, 70, 47, 59, 85, 76, 93, 11, 80, 2, 23, 12, 83, 72, 33, 64, 15, 96, 35, 36, 43, 60, 3, 14, 4, 68, 82, 87, 44, 18, 54, 22, 30, 37, 24, 67, 63, 29, 52, 9, 95, 51, 81, 50, 86, 10, 48, 97, 1, 41, 40, 75, 77, 28, 84, 38, 42, 61, 27, 69, 20, 73, 71]

# %%
print(partition(ran,0,len(ran)-1))
# Out:
# [34, 94, 78, 32, 98, 90, 92, 0, 58, 88, 46, 66, 56, 26, 16, 74, 62, 8, 6, 70, 76, 80, 2, 12, 72, 64, 96, 36, 60, 14, 4, 68, 82, 44, 18, 54, 22, 30, 24, 52, 50, 86, 10, 48, 40, 28, 84, 38, 42, 20, 71, 33, 7, 15, 25, 35, 91, 43, 55, 3, 79, 31, 99, 53, 87, 21, 49, 13, 17, 57, 37, 65, 67, 63, 29, 47, 9, 95, 51, 81, 59, 85, 89, 93, 97, 1, 41, 11, 75, 77, 45, 19, 23, 39, 61, 27, 69, 83, 73, 5]
